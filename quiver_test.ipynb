# %%
# !pip install pyproj

# %%
import json
import os

import matplotlib.pyplot as plt
import numpy as np
import pyproj

import mplleaflet

# %%
# Load up the geojson data
filename = os.path.join('../mplleaflet/examples', 'data', 'track.geojson')
with open(filename) as f:
    gj = json.load(f)

# %%
features = [feat for feat in gj['features'][::10]]
features
# Out:
# [{'type': 'Feature',
#   'id': '0',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.60285133455481, 42.35857187655945]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 55.56803512573242,
#    'time': '2014-01-05 20:08:41.342',
#    'altitude': 89,
#    'speed': 26.90129661560059}},
#  {'type': 'Feature',
#   'id': '10',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.60016015037911, 42.35978095574557]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 60.03398132324219,
#    'time': '2014-01-05 20:08:51.025',
#    'altitude': 92,
#    'speed': 26.14530944824219}},
#  {'type': 'Feature',
#   'id': '20',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.59756879343313, 42.36073859087215]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 66.33683776855469,
#    'time': '2014-01-05 20:09:01.198',
#    'altitude': 96,
#    'speed': 23.69427490234375}},
#  {'type': 'Feature',
#   'id': '30',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.59523354149637, 42.36146491844045]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 68.09986877441406,
#    'time': '2014-01-05 20:09:11.005',
#    'altitude': 99,
#    'speed': 18.8041934967041}},
#  {'type': 'Feature',
#   'id': '40',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5934969646354, 42.36173495393965]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 95.11730194091797,
#    'time': '2014-01-05 20:09:21.121',
#    'altitude': 97,
#    'speed': 14.41900825500488}},
#  {'type': 'Feature',
#   'id': '50',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5919519407697, 42.36100324220423]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 119.7449340820312,
#    'time': '2014-01-05 20:09:31.036',
#    'altitude': 95,
#    'speed': 14.65022754669189}},
#  {'type': 'Feature',
#   'id': '60',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.58988426408087, 42.36107044209896]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 79.52037811279297,
#    'time': '2014-01-05 20:09:41.000',
#    'altitude': 97,
#    'speed': 16.03965377807617}},
#  {'type': 'Feature',
#   'id': '70',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.58812113514882, 42.36046971507101]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 136.2219543457031,
#    'time': '2014-01-05 20:09:51.073',
#    'altitude': 100,
#    'speed': 19.54412460327148}},
#  {'type': 'Feature',
#   'id': '80',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.58622778519485, 42.35882164043559]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 141.220947265625,
#    'time': '2014-01-05 20:10:01.178',
#    'altitude': 103,
#    'speed': 25.67509078979492}},
#  {'type': 'Feature',
#   'id': '90',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5841347034456, 42.35694109952532]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 142.2323760986328,
#    'time': '2014-01-05 20:10:11.166',
#    'altitude': 109,
#    'speed': 27.77922248840332}},
#  {'type': 'Feature',
#   'id': '100',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.58201712002575, 42.35481183248446]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 144.1357116699219,
#    'time': '2014-01-05 20:10:21.148',
#    'altitude': 115,
#    'speed': 30.05895614624023}},
#  {'type': 'Feature',
#   'id': '110',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57980677963073, 42.35253818578472]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 144.2620849609375,
#    'time': '2014-01-05 20:10:31.019',
#    'altitude': 121,
#    'speed': 30.75066757202148}},
#  {'type': 'Feature',
#   'id': '120',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57763848087897, 42.35025711361538]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 148.0078125,
#    'time': '2014-01-05 20:10:41.068',
#    'altitude': 126,
#    'speed': 30.0322151184082}},
#  {'type': 'Feature',
#   'id': '130',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57610953792145, 42.34775972556541]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 160.6640625,
#    'time': '2014-01-05 20:10:51.086',
#    'altitude': 129,
#    'speed': 30.60987663269043}},
#  {'type': 'Feature',
#   'id': '140',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5754347259641, 42.34518071831178]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 175.6304016113281,
#    'time': '2014-01-05 20:11:01.102',
#    'altitude': 136,
#    'speed': 28.89267349243164}},
#  {'type': 'Feature',
#   'id': '150',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57548693015387, 42.34239660673062]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 182.4609375,
#    'time': '2014-01-05 20:11:11.101',
#    'altitude': 131,
#    'speed': 31.99265670776367}},
#  {'type': 'Feature',
#   'id': '160',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57566906890979, 42.33958016153642]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 3,
#    'course': 183.515625,
#    'time': '2014-01-05 20:11:21.093',
#    'altitude': 129,
#    'speed': 31.04525947570801}},
#  {'type': 'Feature',
#   'id': '170',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57582413411846, 42.3367863474808]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 181.7578125,
#    'time': '2014-01-05 20:11:31.007',
#    'altitude': 126,
#    'speed': 30.965087890625}},
#  {'type': 'Feature',
#   'id': '180',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57591935253849, 42.33391399499246]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 177.890625,
#    'time': '2014-01-05 20:11:41.101',
#    'altitude': 125,
#    'speed': 32.00207138061523}},
#  {'type': 'Feature',
#   'id': '190',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57548786908112, 42.33093943894341]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 12,
#    'course': 171.5268096923828,
#    'time': '2014-01-05 20:11:52.922',
#    'altitude': 126,
#    'speed': 31.89579963684082}},
#  {'type': 'Feature',
#   'id': '200',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5747325277919, 42.32819600248287]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 165.9209594726562,
#    'time': '2014-01-05 20:12:02.846',
#    'altitude': 124,
#    'speed': 31.71041297912598}},
#  {'type': 'Feature',
#   'id': '210',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57352791201177, 42.32541724947451]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 162.16552734375,
#    'time': '2014-01-05 20:12:12.831',
#    'altitude': 123,
#    'speed': 33.08620834350586}},
#  {'type': 'Feature',
#   'id': '220',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.57229509683827, 42.3226446031148]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 161.7725524902344,
#    'time': '2014-01-05 20:12:22.842',
#    'altitude': 119,
#    'speed': 32.53999710083008}},
#  {'type': 'Feature',
#   'id': '230',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5709916507903, 42.31982178644203]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 162.2063446044922,
#    'time': '2014-01-05 20:12:32.829',
#    'altitude': 114,
#    'speed': 33.46945953369141}},
#  {'type': 'Feature',
#   'id': '240',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56971054158319, 42.31685330163903]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 161.71875,
#    'time': '2014-01-05 20:12:42.835',
#    'altitude': 110,
#    'speed': 35.17794036865234}},
#  {'type': 'Feature',
#   'id': '250',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56847999437858, 42.31386351868726]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 163.828125,
#    'time': '2014-01-05 20:12:52.820',
#    'altitude': 97,
#    'speed': 34.65785598754883}},
#  {'type': 'Feature',
#   'id': '260',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56724575913657, 42.31089259501762]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 162.7734375,
#    'time': '2014-01-05 20:13:02.869',
#    'altitude': 89,
#    'speed': 34.71480941772461}},
#  {'type': 'Feature',
#   'id': '270',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56613289385248, 42.30792359918571]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 166.640625,
#    'time': '2014-01-05 20:13:12.873',
#    'altitude': 92,
#    'speed': 34.15212631225586}},
#  {'type': 'Feature',
#   'id': '280',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56550131744851, 42.3049657093755]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 175.078125,
#    'time': '2014-01-05 20:13:22.843',
#    'altitude': 91,
#    'speed': 33.06000137329102}},
#  {'type': 'Feature',
#   'id': '290',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5655759753832, 42.30216976615682]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 186.5768737792969,
#    'time': '2014-01-05 20:13:32.836',
#    'altitude': 101,
#    'speed': 30.24623107910156}},
#  {'type': 'Feature',
#   'id': '300',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56642491380953, 42.29949429211621]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 196.7879486083984,
#    'time': '2014-01-05 20:13:42.866',
#    'altitude': 105,
#    'speed': 29.45183753967285}},
#  {'type': 'Feature',
#   'id': '310',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56749865403629, 42.29682122721124]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 194.7197113037109,
#    'time': '2014-01-05 20:13:52.843',
#    'altitude': 108,
#    'speed': 31.42990303039551}},
#  {'type': 'Feature',
#   'id': '320',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56820890971768, 42.29411357847904]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 184.0634002685547,
#    'time': '2014-01-05 20:14:02.836',
#    'altitude': 115,
#    'speed': 30.92909049987793}},
#  {'type': 'Feature',
#   'id': '330',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56805922283937, 42.29135735430037]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 172.265625,
#    'time': '2014-01-05 20:14:12.922',
#    'altitude': 126,
#    'speed': 31.35860252380371}},
#  {'type': 'Feature',
#   'id': '340',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5675938358628, 42.28869193038263]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 174.6567993164062,
#    'time': '2014-01-05 20:14:23.224',
#    'altitude': 128,
#    'speed': 29.33007431030273}},
#  {'type': 'Feature',
#   'id': '350',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5671548850181, 42.28598131727937]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 176.5834045410156,
#    'time': '2014-01-05 20:14:32.919',
#    'altitude': 129,
#    'speed': 31.0949821472168}},
#  {'type': 'Feature',
#   'id': '360',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56713516310387, 42.2830557276337]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 180.9240570068359,
#    'time': '2014-01-05 20:14:42.839',
#    'altitude': 123,
#    'speed': 32.90602874755859}},
#  {'type': 'Feature',
#   'id': '370',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56701379651169, 42.28014868673218]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 173.8568267822266,
#    'time': '2014-01-05 20:14:52.999',
#    'altitude': 114,
#    'speed': 32.25394439697266}},
#  {'type': 'Feature',
#   'id': '380',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56653706922341, 42.2773181274927]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 173.3203125,
#    'time': '2014-01-05 20:15:02.933',
#    'altitude': 110,
#    'speed': 31.31030464172363}},
#  {'type': 'Feature',
#   'id': '390',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56603685710049, 42.27462821669101]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 172.39111328125,
#    'time': '2014-01-05 20:15:13.042',
#    'altitude': 102,
#    'speed': 29.98251342773438}},
#  {'type': 'Feature',
#   'id': '400',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56557795622224, 42.2721733569826]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 172.5109558105469,
#    'time': '2014-01-05 20:15:23.244',
#    'altitude': 97,
#    'speed': 27.39624977111816}},
#  {'type': 'Feature',
#   'id': '410',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56512689783384, 42.26944760423365]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 171.9140625,
#    'time': '2014-01-05 20:15:32.809',
#    'altitude': 98,
#    'speed': 29.64575576782227}},
#  {'type': 'Feature',
#   'id': '420',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56466924592067, 42.26697942711624]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 171.9140625,
#    'time': '2014-01-05 20:15:42.839',
#    'altitude': 99,
#    'speed': 26.46159744262695}},
#  {'type': 'Feature',
#   'id': '430',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56429692178179, 42.26505519360515]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 8,
#    'course': 171.2109375,
#    'time': '2014-01-05 20:15:53.142',
#    'altitude': 99,
#    'speed': 20.46040916442871}},
#  {'type': 'Feature',
#   'id': '440',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56426414854039, 42.26360713601323]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 191.953125,
#    'time': '2014-01-05 20:16:03.023',
#    'altitude': 95,
#    'speed': 16.18527412414551}},
#  {'type': 'Feature',
#   'id': '450',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56532130129341, 42.26288129563181]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 262.9421691894531,
#    'time': '2014-01-05 20:16:13.042',
#    'altitude': 96,
#    'speed': 10.34786128997803}},
#  {'type': 'Feature',
#   'id': '460',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5665726100894, 42.2631144956607]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 287.4709167480469,
#    'time': '2014-01-05 20:16:22.900',
#    'altitude': 95,
#    'speed': 9.775680541992188}},
#  {'type': 'Feature',
#   'id': '470',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56770723924991, 42.26339148853104]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 294.547607421875,
#    'time': '2014-01-05 20:16:32.828',
#    'altitude': 95,
#    'speed': 9.775652885437012}},
#  {'type': 'Feature',
#   'id': '480',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56821390178668, 42.26425028927363]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 9.162127494812012,
#    'time': '2014-01-05 20:16:42.944',
#    'altitude': 94,
#    'speed': 11.92220401763916}},
#  {'type': 'Feature',
#   'id': '490',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56741850233114, 42.2652157693618]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 51.02409362792969,
#    'time': '2014-01-05 20:16:53.058',
#    'altitude': 92,
#    'speed': 10.41044807434082}},
#  {'type': 'Feature',
#   'id': '500',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56520046726625, 42.26627627852699]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 59.23395538330078,
#    'time': '2014-01-05 20:17:03.043',
#    'altitude': 94,
#    'speed': 25.39401626586914}},
#  {'type': 'Feature',
#   'id': '510',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.56241945362001, 42.267506292951]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 59.86021423339844,
#    'time': '2014-01-05 20:17:13.017',
#    'altitude': 95,
#    'speed': 27.2478084564209}},
#  {'type': 'Feature',
#   'id': '520',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.55952719625114, 42.26877654514139]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 59.64922332763672,
#    'time': '2014-01-05 20:17:22.842',
#    'altitude': 100,
#    'speed': 28.19510269165039}},
#  {'type': 'Feature',
#   'id': '530',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.55646399003672, 42.27005087863989]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 64.29004669189453,
#    'time': '2014-01-05 20:17:32.968',
#    'altitude': 96,
#    'speed': 29.56429290771484}},
#  {'type': 'Feature',
#   'id': '540',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.55311286456096, 42.27098149251404]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.3671875,
#    'time': '2014-01-05 20:17:42.962',
#    'altitude': 94,
#    'speed': 29.61887550354004}},
#  {'type': 'Feature',
#   'id': '550',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.54980939726813, 42.27178650093628]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 8,
#    'course': 71.24935150146484,
#    'time': '2014-01-05 20:17:52.989',
#    'altitude': 95,
#    'speed': 29.18483734130859}},
#  {'type': 'Feature',
#   'id': '560',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.54652515755204, 42.27268160215425]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 71.24935150146484,
#    'time': '2014-01-05 20:18:02.898',
#    'altitude': 99,
#    'speed': 29.08775520324707}},
#  {'type': 'Feature',
#   'id': '570',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5431058780025, 42.27356156803879]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 72.421875,
#    'time': '2014-01-05 20:18:12.854',
#    'altitude': 100,
#    'speed': 30.17468643188477}},
#  {'type': 'Feature',
#   'id': '580',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.53953395083043, 42.27445035468474]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 71.25829315185547,
#    'time': '2014-01-05 20:18:22.837',
#    'altitude': 101,
#    'speed': 31.40261459350586}},
#  {'type': 'Feature',
#   'id': '590',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.53569692530593, 42.27538652174342]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 71.29339599609375,
#    'time': '2014-01-05 20:18:32.937',
#    'altitude': 103,
#    'speed': 33.37472534179688}},
#  {'type': 'Feature',
#   'id': '600',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.53198733851666, 42.27629398964702]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.3033218383789,
#    'time': '2014-01-05 20:18:42.957',
#    'altitude': 97,
#    'speed': 32.52998733520508}},
#  {'type': 'Feature',
#   'id': '610',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.52832266788924, 42.2772258522162]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 71.3033218383789,
#    'time': '2014-01-05 20:18:52.860',
#    'altitude': 93,
#    'speed': 31.97804832458496}},
#  {'type': 'Feature',
#   'id': '620',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5246609065633, 42.27818590051737]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.3007583618164,
#    'time': '2014-01-05 20:19:02.946',
#    'altitude': 92,
#    'speed': 30.42962265014648}},
#  {'type': 'Feature',
#   'id': '630',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.52098963975116, 42.27910401769194]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.3671875,
#    'time': '2014-01-05 20:19:12.863',
#    'altitude': 95,
#    'speed': 31.48841667175293}},
#  {'type': 'Feature',
#   'id': '640',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.51733357197733, 42.28002894152241]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.26416778564453,
#    'time': '2014-01-05 20:19:22.913',
#    'altitude': 99,
#    'speed': 32.19875717163086}},
#  {'type': 'Feature',
#   'id': '650',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.51368629467146, 42.28088136193067]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 70.52729034423828,
#    'time': '2014-01-05 20:19:32.873',
#    'altitude': 100,
#    'speed': 30.55706977844238}},
#  {'type': 'Feature',
#   'id': '660',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.51022629907456, 42.28182069954046]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 69.17630767822266,
#    'time': '2014-01-05 20:19:42.950',
#    'altitude': 98,
#    'speed': 30.84166717529297}},
#  {'type': 'Feature',
#   'id': '670',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.50680357127275, 42.28275298093364]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 69.13778686523438,
#    'time': '2014-01-05 20:19:52.863',
#    'altitude': 98,
#    'speed': 30.0409984588623}},
#  {'type': 'Feature',
#   'id': '680',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.5035832168503, 42.28370647363195]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 69.13778686523438,
#    'time': '2014-01-05 20:20:02.886',
#    'altitude': 100,
#    'speed': 28.47291946411133}},
#  {'type': 'Feature',
#   'id': '690',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.50028208165914, 42.28467189889375]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 69.29903411865234,
#    'time': '2014-01-05 20:20:12.897',
#    'altitude': 106,
#    'speed': 29.91006469726562}},
#  {'type': 'Feature',
#   'id': '700',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.49676345844186, 42.2856990565532]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 66.4477310180664,
#    'time': '2014-01-05 20:20:22.832',
#    'altitude': 104,
#    'speed': 31.14809226989746}},
#  {'type': 'Feature',
#   'id': '710',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.49347891683671, 42.28699808117477]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 56.69773864746094,
#    'time': '2014-01-05 20:20:32.824',
#    'altitude': 103,
#    'speed': 30.62065696716309}},
#  {'type': 'Feature',
#   'id': '720',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.49050065009322, 42.28873153258333]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 48.63818740844727,
#    'time': '2014-01-05 20:20:42.859',
#    'altitude': 105,
#    'speed': 31.45454025268555}},
#  {'type': 'Feature',
#   'id': '730',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.48763368844193, 42.29068382647102]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 48.1640625,
#    'time': '2014-01-05 20:20:52.941',
#    'altitude': 106,
#    'speed': 31.9893856048584}},
#  {'type': 'Feature',
#   'id': '740',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.48462332791787, 42.29269141800915]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 48.1640625,
#    'time': '2014-01-05 20:21:02.905',
#    'altitude': 98,
#    'speed': 33.23876571655273}},
#  {'type': 'Feature',
#   'id': '750',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.48167231126826, 42.29466225490187]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 48.515625,
#    'time': '2014-01-05 20:21:12.825',
#    'altitude': 91,
#    'speed': 32.56818389892578}},
#  {'type': 'Feature',
#   'id': '760',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.47881165153484, 42.29662370406305]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 47.4609375,
#    'time': '2014-01-05 20:21:22.899',
#    'altitude': 77,
#    'speed': 31.72107887268066}},
#  {'type': 'Feature',
#   'id': '770',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.47597444858346, 42.29849379764288]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 52.4433708190918,
#    'time': '2014-01-05 20:21:32.826',
#    'altitude': 76,
#    'speed': 30.90003967285156}},
#  {'type': 'Feature',
#   'id': '780',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.47283886871682, 42.29990101499019]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 66.8014144897461,
#    'time': '2014-01-05 20:21:42.828',
#    'altitude': 73,
#    'speed': 30.40422248840332}},
#  {'type': 'Feature',
#   'id': '790',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.46932352041509, 42.30071902823379]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 79.77188110351562,
#    'time': '2014-01-05 20:21:52.829',
#    'altitude': 67,
#    'speed': 30.96223831176758}},
#  {'type': 'Feature',
#   'id': '800',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.46566078073481, 42.30100199118471]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 84.375,
#    'time': '2014-01-05 20:22:02.864',
#    'altitude': 65,
#    'speed': 30.16571807861328}},
#  {'type': 'Feature',
#   'id': '810',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.46216654570766, 42.30121958398659]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 85.20171356201172,
#    'time': '2014-01-05 20:22:12.811',
#    'altitude': 66,
#    'speed': 28.47802925109863}},
#  {'type': 'Feature',
#   'id': '820',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.45867866684296, 42.30146230357608]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 85.20171356201172,
#    'time': '2014-01-05 20:22:22.828',
#    'altitude': 65,
#    'speed': 28.9204158782959}},
#  {'type': 'Feature',
#   'id': '830',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.45519932738641, 42.30163344186013]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 83.671875,
#    'time': '2014-01-05 20:22:32.944',
#    'altitude': 63,
#    'speed': 28.81996726989746}},
#  {'type': 'Feature',
#   'id': '840',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.4518355020056, 42.30222105518197]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 72.0703125,
#    'time': '2014-01-05 20:22:42.860',
#    'altitude': 64,
#    'speed': 28.4782657623291}},
#  {'type': 'Feature',
#   'id': '850',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.44840260974266, 42.30336053300864]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 61.5234375,
#    'time': '2014-01-05 20:22:52.968',
#    'altitude': 66,
#    'speed': 31.15018844604492}},
#  {'type': 'Feature',
#   'id': '860',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.44542070169246, 42.30487834291019]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 50.78933334350586,
#    'time': '2014-01-05 20:23:02.839',
#    'altitude': 64,
#    'speed': 29.41969108581543}},
#  {'type': 'Feature',
#   'id': '870',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.44247599341304, 42.30665459403891]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 50.73535919189453,
#    'time': '2014-01-05 20:23:12.871',
#    'altitude': 61,
#    'speed': 30.52967834472656}},
#  {'type': 'Feature',
#   'id': '880',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.43963555337005, 42.3083408224426]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 57.94985198974609,
#    'time': '2014-01-05 20:23:22.997',
#    'altitude': 59,
#    'speed': 29.53002738952637}},
#  {'type': 'Feature',
#   'id': '890',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.43643561258762, 42.3094221621777]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 70.87478637695312,
#    'time': '2014-01-05 20:23:33.056',
#    'altitude': 60,
#    'speed': 28.59922981262207}},
#  {'type': 'Feature',
#   'id': '900',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.4332187921474, 42.31018662922299]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 70.6640625,
#    'time': '2014-01-05 20:23:42.900',
#    'altitude': 58,
#    'speed': 27.62224006652832}},
#  {'type': 'Feature',
#   'id': '910',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.43004154212399, 42.31095956441393]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.22602844238281,
#    'time': '2014-01-05 20:23:52.840',
#    'altitude': 56,
#    'speed': 28.66562652587891}},
#  {'type': 'Feature',
#   'id': '920',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.42671279913863, 42.31176979445641]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.47984313964844,
#    'time': '2014-01-05 20:24:02.927',
#    'altitude': 55,
#    'speed': 28.86024475097656}},
#  {'type': 'Feature',
#   'id': '930',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.42340425408578, 42.31260895733006]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.3671875,
#    'time': '2014-01-05 20:24:12.913',
#    'altitude': 53,
#    'speed': 29.04841613769531}},
#  {'type': 'Feature',
#   'id': '940',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.42001356191169, 42.31343551405531]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 71.64430236816406,
#    'time': '2014-01-05 20:24:22.818',
#    'altitude': 54,
#    'speed': 29.18989944458008}},
#  {'type': 'Feature',
#   'id': '950',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.41658878607149, 42.31430594113621]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 70.8779296875,
#    'time': '2014-01-05 20:24:32.826',
#    'altitude': 51,
#    'speed': 29.35243034362793}},
#  {'type': 'Feature',
#   'id': '960',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.41321173581618, 42.31515610120092]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.364013671875,
#    'time': '2014-01-05 20:24:42.843',
#    'altitude': 58,
#    'speed': 29.76141166687012}},
#  {'type': 'Feature',
#   'id': '970',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.40964661731516, 42.31591557622171]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 78.3984375,
#    'time': '2014-01-05 20:24:52.906',
#    'altitude': 57,
#    'speed': 31.07124900817871}},
#  {'type': 'Feature',
#   'id': '980',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.40583453290256, 42.31605630453078]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 92.73927307128906,
#    'time': '2014-01-05 20:25:02.973',
#    'altitude': 57,
#    'speed': 31.16201019287109}},
#  {'type': 'Feature',
#   'id': '990',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.40217857080201, 42.31569164221363]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 103.0037002563477,
#    'time': '2014-01-05 20:25:13.089',
#    'altitude': 64,
#    'speed': 30.273193359375}},
#  {'type': 'Feature',
#   'id': '1000',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.39859021647963, 42.31501066595531]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 104.0625,
#    'time': '2014-01-05 20:25:23.120',
#    'altitude': 63,
#    'speed': 29.95977210998535}},
#  {'type': 'Feature',
#   'id': '1010',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.39507870196495, 42.31439044703014]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 103.359375,
#    'time': '2014-01-05 20:25:32.820',
#    'altitude': 58,
#    'speed': 29.59947967529297}},
#  {'type': 'Feature',
#   'id': '1020',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.39152309799655, 42.31381249893037]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 101.8627319335938,
#    'time': '2014-01-05 20:25:42.873',
#    'altitude': 56,
#    'speed': 30.21941566467285}},
#  {'type': 'Feature',
#   'id': '1030',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.38792260775915, 42.31321592906724]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 110.7990264892578,
#    'time': '2014-01-05 20:25:53.027',
#    'altitude': 56,
#    'speed': 30.33800315856934}},
#  {'type': 'Feature',
#   'id': '1040',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.38442131510274, 42.31269214907236]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 101.5877532958984,
#    'time': '2014-01-05 20:26:03.080',
#    'altitude': 54,
#    'speed': 28.55154418945312}},
#  {'type': 'Feature',
#   'id': '1050',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.38059046510354, 42.31211789529939]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 101.3099212646484,
#    'time': '2014-01-05 20:26:13.136',
#    'altitude': 52,
#    'speed': 31.24666213989258}},
#  {'type': 'Feature',
#   'id': '1060',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.37682970619889, 42.31152387805498]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 101.6015625,
#    'time': '2014-01-05 20:26:22.839',
#    'altitude': 56,
#    'speed': 31.54623985290527}},
#  {'type': 'Feature',
#   'id': '1070',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.37319270476439, 42.31100461839939]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 95.9061508178711,
#    'time': '2014-01-05 20:26:32.888',
#    'altitude': 54,
#    'speed': 30.12717819213867}},
#  {'type': 'Feature',
#   'id': '1080',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.36945265752378, 42.31102878967906]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 80.50313568115234,
#    'time': '2014-01-05 20:26:42.986',
#    'altitude': 52,
#    'speed': 29.55900192260742}},
#  {'type': 'Feature',
#   'id': '1090',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.36598494841844, 42.31174842924095]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 72.421875,
#    'time': '2014-01-05 20:26:52.993',
#    'altitude': 51,
#    'speed': 30.22998046875}},
#  {'type': 'Feature',
#   'id': '1100',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.36278331286401, 42.3130340455494]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 57.3046875,
#    'time': '2014-01-05 20:27:03.038',
#    'altitude': 56,
#    'speed': 29.97644996643066}},
#  {'type': 'Feature',
#   'id': '1110',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.36002244488998, 42.31474534327504]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 51.47396087646484,
#    'time': '2014-01-05 20:27:12.819',
#    'altitude': 60,
#    'speed': 29.68575668334961}},
#  {'type': 'Feature',
#   'id': '1120',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.35683243374461, 42.31620221491647]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 66.33235168457031,
#    'time': '2014-01-05 20:27:22.842',
#    'altitude': 54,
#    'speed': 30.77980804443359}},
#  {'type': 'Feature',
#   'id': '1130',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.35331707848859, 42.3169769484991]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 78.92765808105469,
#    'time': '2014-01-05 20:27:33.007',
#    'altitude': 54,
#    'speed': 30.92939949035645}},
#  {'type': 'Feature',
#   'id': '1140',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.34945098786535, 42.31748814234895]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 4,
#    'course': 76.44155883789062,
#    'time': '2014-01-05 20:27:43.010',
#    'altitude': 56,
#    'speed': 32.02957534790039}},
#  {'type': 'Feature',
#   'id': '1150',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.34581632918804, 42.31845776554413]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 65.0390625,
#    'time': '2014-01-05 20:27:53.042',
#    'altitude': 58,
#    'speed': 31.85375213623047}},
#  {'type': 'Feature',
#   'id': '1160',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.34250547743527, 42.32000267602719]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 53.7890625,
#    'time': '2014-01-05 20:28:02.955',
#    'altitude': 60,
#    'speed': 32.60100173950195}},
#  {'type': 'Feature',
#   'id': '1170',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.33957424207715, 42.32191002000339]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 3,
#    'course': 45.3515625,
#    'time': '2014-01-05 20:28:12.889',
#    'altitude': 58,
#    'speed': 32.48606872558594}},
#  {'type': 'Feature',
#   'id': '1180',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.33707815566511, 42.32391158662324]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 43.51875686645508,
#    'time': '2014-01-05 20:28:22.975',
#    'altitude': 65,
#    'speed': 30.53135108947754}},
#  {'type': 'Feature',
#   'id': '1190',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.33452686118834, 42.32580631873869]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 47.0937385559082,
#    'time': '2014-01-05 20:28:32.833',
#    'altitude': 67,
#    'speed': 28.71010780334473}},
#  {'type': 'Feature',
#   'id': '1200',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.33164697665747, 42.32750767060349]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 55.93910217285156,
#    'time': '2014-01-05 20:28:42.816',
#    'altitude': 70,
#    'speed': 30.86617469787598}},
#  {'type': 'Feature',
#   'id': '1210',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.3284630349159, 42.32895410533467]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 59.26073455810547,
#    'time': '2014-01-05 20:28:52.857',
#    'altitude': 69,
#    'speed': 30.28236961364746}},
#  {'type': 'Feature',
#   'id': '1220',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.3253615024084, 42.33029409124997]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 59.36999893188477,
#    'time': '2014-01-05 20:29:02.923',
#    'altitude': 67,
#    'speed': 29.9093189239502}},
#  {'type': 'Feature',
#   'id': '1230',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.32221104583826, 42.33168357055851]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 59.0625,
#    'time': '2014-01-05 20:29:12.922',
#    'altitude': 64,
#    'speed': 30.94872665405273}},
#  {'type': 'Feature',
#   'id': '1240',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.31905014633324, 42.33306117825427]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 59.765625,
#    'time': '2014-01-05 20:29:22.915',
#    'altitude': 63,
#    'speed': 30.02742004394531}},
#  {'type': 'Feature',
#   'id': '1250',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.31582881330635, 42.33428556476006]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 6,
#    'course': 67.5,
#    'time': '2014-01-05 20:29:32.842',
#    'altitude': 64,
#    'speed': 29.78481483459473}},
#  {'type': 'Feature',
#   'id': '1260',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.31230162258552, 42.33502126433768]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 79.41436767578125,
#    'time': '2014-01-05 20:29:42.849',
#    'altitude': 66,
#    'speed': 30.86371231079102}},
#  {'type': 'Feature',
#   'id': '1270',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.30844100638197, 42.33524154419272]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 89.474365234375,
#    'time': '2014-01-05 20:29:52.945',
#    'altitude': 69,
#    'speed': 31.49991798400879}},
#  {'type': 'Feature',
#   'id': '1280',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.30470362940916, 42.33520972577506]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 91.4017333984375,
#    'time': '2014-01-05 20:30:02.924',
#    'altitude': 74,
#    'speed': 31.30273818969727}},
#  {'type': 'Feature',
#   'id': '1290',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.30086764642408, 42.3352093567926]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 84.48286437988281,
#    'time': '2014-01-05 20:30:12.893',
#    'altitude': 74,
#    'speed': 30.96844100952148}},
#  {'type': 'Feature',
#   'id': '1300',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.29716368932509, 42.33571792455561]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 73.59795379638672,
#    'time': '2014-01-05 20:30:22.840',
#    'altitude': 84,
#    'speed': 31.03156471252441}},
#  {'type': 'Feature',
#   'id': '1310',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.2937052270218, 42.33644321359169]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 74.22621154785156,
#    'time': '2014-01-05 20:30:32.929',
#    'altitude': 84,
#    'speed': 29.62521553039551}},
#  {'type': 'Feature',
#   'id': '1320',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.29019058316135, 42.33716005463371]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 74.53125,
#    'time': '2014-01-05 20:30:42.881',
#    'altitude': 78,
#    'speed': 30.08783340454102}},
#  {'type': 'Feature',
#   'id': '1330',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.28670184178694, 42.33793943292493]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 12,
#    'course': 74.68087005615234,
#    'time': '2014-01-05 20:30:53.110',
#    'altitude': 79,
#    'speed': 29.84806251525879}},
#  {'type': 'Feature',
#   'id': '1340',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.28314645324126, 42.33837160105121]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 84.13249206542969,
#    'time': '2014-01-05 20:31:03.043',
#    'altitude': 73,
#    'speed': 30.47149276733398}},
#  {'type': 'Feature',
#   'id': '1350',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.27944867133282, 42.33864151410976]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 83.671875,
#    'time': '2014-01-05 20:31:13.011',
#    'altitude': 61,
#    'speed': 31.85124015808105}},
#  {'type': 'Feature',
#   'id': '1360',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.27581042244218, 42.33887679413179]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 84.0234375,
#    'time': '2014-01-05 20:31:23.125',
#    'altitude': 50,
#    'speed': 29.33184432983398}},
#  {'type': 'Feature',
#   'id': '1370',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.27249542882669, 42.33895916231992]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 93.6522216796875,
#    'time': '2014-01-05 20:31:32.854',
#    'altitude': 40,
#    'speed': 27.43963050842285}},
#  {'type': 'Feature',
#   'id': '1380',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.26944626961226, 42.33886437218133]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 92.16694641113281,
#    'time': '2014-01-05 20:31:42.976',
#    'altitude': 36,
#    'speed': 24.30670928955078}},
#  {'type': 'Feature',
#   'id': '1390',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.2667133517747, 42.33883486690671]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 86.75265502929688,
#    'time': '2014-01-05 20:31:53.072',
#    'altitude': 37,
#    'speed': 22.58365249633789}},
#  {'type': 'Feature',
#   'id': '1400',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.26519891215217, 42.33905940156561]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 73.37374114990234,
#    'time': '2014-01-05 20:32:02.834',
#    'altitude': 32,
#    'speed': 11.38099098205566}},
#  {'type': 'Feature',
#   'id': '1410',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.26429063373024, 42.33925338180738]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 69.04419708251953,
#    'time': '2014-01-05 20:32:12.927',
#    'altitude': 32,
#    'speed': 10.85709476470947}},
#  {'type': 'Feature',
#   'id': '1420',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.26230238957365, 42.34016492310168]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 51.71001052856445,
#    'time': '2014-01-05 20:32:22.871',
#    'altitude': 35,
#    'speed': 20.40934562683105}},
#  {'type': 'Feature',
#   'id': '1430',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.26013308907808, 42.34147302526756]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 52.25330352783203,
#    'time': '2014-01-05 20:32:32.978',
#    'altitude': 39,
#    'speed': 23.84601020812988}},
#  {'type': 'Feature',
#   'id': '1440',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.25712288550218, 42.34243306800941]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 71.015625,
#    'time': '2014-01-05 20:32:43.048',
#    'altitude': 34,
#    'speed': 28.80675315856934}},
#  {'type': 'Feature',
#   'id': '1450',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.25399197241612, 42.34354773420996]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 50.52753829956055,
#    'time': '2014-01-05 20:32:53.093',
#    'altitude': 37,
#    'speed': 27.35242462158203}},
#  {'type': 'Feature',
#   'id': '1460',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.25129141190398, 42.34520419835059]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 58.96181869506836,
#    'time': '2014-01-05 20:33:02.927',
#    'altitude': 37,
#    'speed': 29.26703453063965}},
#  {'type': 'Feature',
#   'id': '1470',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.24798982856868, 42.34606297708071]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 82.56859588623047,
#    'time': '2014-01-05 20:33:12.943',
#    'altitude': 32,
#    'speed': 29.16225051879883}},
#  {'type': 'Feature',
#   'id': '1480',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.24447979039628, 42.34648693356881]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 79.453125,
#    'time': '2014-01-05 20:33:23.008',
#    'altitude': 29,
#    'speed': 29.10988426208496}},
#  {'type': 'Feature',
#   'id': '1490',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.24068010605056, 42.34675942924092]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 80.5078125,
#    'time': '2014-01-05 20:33:33.034',
#    'altitude': 29,
#    'speed': 31.45578956604004}},
#  {'type': 'Feature',
#   'id': '1500',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.23688595376092, 42.34704537786762]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 86.484375,
#    'time': '2014-01-05 20:33:42.820',
#    'altitude': 28,
#    'speed': 31.18480682373047}},
#  {'type': 'Feature',
# ...
#    'course': 75.86825561523438,
#    'time': '2014-01-05 20:34:23.041',
#    'altitude': 19,
#    'speed': 31.73177528381348}},
#  {'type': 'Feature',
#   'id': '1550',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.21823532677922, 42.34938558905202]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 73.04592895507812,
#    'time': '2014-01-05 20:34:32.831',
#    'altitude': 21,
#    'speed': 31.57865333557129}},
#  {'type': 'Feature',
#   'id': '1560',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.2144265673794, 42.35015013536756]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 79.00911712646484,
#    'time': '2014-01-05 20:34:42.833',
#    'altitude': 22,
#    'speed': 32.05024719238281}},
#  {'type': 'Feature',
#   'id': '1570',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.21044121689276, 42.35066656958531]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 79.8046875,
#    'time': '2014-01-05 20:34:52.836',
#    'altitude': 21,
#    'speed': 33.20285415649414}},
#  {'type': 'Feature',
#   'id': '1580',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.20662761858776, 42.35127501193653]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 75.5859375,
#    'time': '2014-01-05 20:35:03.005',
#    'altitude': 18,
#    'speed': 31.48641967773438}},
#  {'type': 'Feature',
#   'id': '1590',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.20310259551667, 42.35206096361077]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 70.21430206298828,
#    'time': '2014-01-05 20:35:13.008',
#    'altitude': 22,
#    'speed': 30.37589073181152}},
#  {'type': 'Feature',
#   'id': '1600',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.19970498707174, 42.3530140436472]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 8,
#    'course': 67.99930572509766,
#    'time': '2014-01-05 20:35:23.028',
#    'altitude': 25,
#    'speed': 30.11997413635254}},
#  {'type': 'Feature',
#   'id': '1610',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.19625090119398, 42.35405099458359]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 68.71537780761719,
#    'time': '2014-01-05 20:35:32.895',
#    'altitude': 27,
#    'speed': 30.78830337524414}},
#  {'type': 'Feature',
#   'id': '1620',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.19275800144283, 42.35492214404159]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 74.3875732421875,
#    'time': '2014-01-05 20:35:42.867',
#    'altitude': 23,
#    'speed': 30.3427848815918}},
#  {'type': 'Feature',
#   'id': '1630',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.18926366797758, 42.35567060768823]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 74.8828125,
#    'time': '2014-01-05 20:35:52.867',
#    'altitude': 20,
#    'speed': 29.50086784362793}},
#  {'type': 'Feature',
#   'id': '1640',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.18575048626602, 42.35628302540248]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 75.67401885986328,
#    'time': '2014-01-05 20:36:02.875',
#    'altitude': 19,
#    'speed': 28.94483184814453}},
#  {'type': 'Feature',
#   'id': '1650',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.18240700111198, 42.35693957415964]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 74.01292419433594,
#    'time': '2014-01-05 20:36:12.825',
#    'altitude': 16,
#    'speed': 29.69143486022949}},
#  {'type': 'Feature',
#   'id': '1660',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.17898168359471, 42.35767030946381]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 78.52237701416016,
#    'time': '2014-01-05 20:36:22.889',
#    'altitude': 19,
#    'speed': 29.21115493774414}},
#  {'type': 'Feature',
#   'id': '1670',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.17561088027976, 42.35779472985843]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 92.97022247314453,
#    'time': '2014-01-05 20:36:32.848',
#    'altitude': 24,
#    'speed': 26.77063941955566}},
#  {'type': 'Feature',
#   'id': '1680',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1724917818775, 42.35765916455593]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 93.94867706298828,
#    'time': '2014-01-05 20:36:42.885',
#    'altitude': 23,
#    'speed': 24.9041805267334}},
#  {'type': 'Feature',
#   'id': '1690',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.16920694715452, 42.35752757642638]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 91.7578125,
#    'time': '2014-01-05 20:36:52.964',
#    'altitude': 23,
#    'speed': 27.56999588012695}},
#  {'type': 'Feature',
#   'id': '1700',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.16555872379911, 42.3574790032975]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 88.2421875,
#    'time': '2014-01-05 20:37:02.865',
#    'altitude': 20,
#    'speed': 30.0599250793457}},
#  {'type': 'Feature',
#   'id': '1710',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.16170221014987, 42.35757786784541]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 8,
#    'course': 87.5390625,
#    'time': '2014-01-05 20:37:12.971',
#    'altitude': 22,
#    'speed': 31.57048797607422}},
#  {'type': 'Feature',
#   'id': '1720',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.15796698263954, 42.3576870002247]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 8,
#    'course': 87.5390625,
#    'time': '2014-01-05 20:37:22.990',
#    'altitude': 20,
#    'speed': 30.77991676330566}},
#  {'type': 'Feature',
#   'id': '1730',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1543424800701, 42.35781918283772]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 87.1875,
#    'time': '2014-01-05 20:37:33.016',
#    'altitude': 20,
#    'speed': 29.91995811462402}},
#  {'type': 'Feature',
#   'id': '1740',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.15070473409365, 42.35794683922302]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 84.375,
#    'time': '2014-01-05 20:37:43.007',
#    'altitude': 18,
#    'speed': 29.52010536193848}},
#  {'type': 'Feature',
#   'id': '1750',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1470772299727, 42.35834345208408]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 88.46012115478516,
#    'time': '2014-01-05 20:37:52.849',
#    'altitude': 24,
#    'speed': 30.87991333007812}},
#  {'type': 'Feature',
#   'id': '1760',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.14315179082593, 42.35795938114621]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 99.59890747070312,
#    'time': '2014-01-05 20:38:03.028',
#    'altitude': 20,
#    'speed': 32.13578796386719}},
#  {'type': 'Feature',
#   'id': '1770',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.13929037922777, 42.35747909608134]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 99.80970001220703,
#    'time': '2014-01-05 20:38:13.053',
#    'altitude': 17,
#    'speed': 32.33039855957031}},
#  {'type': 'Feature',
#   'id': '1780',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.12699553999997, 42.36154078999999]},
#   'properties': {'horizontal_accuracy': 1414,
#    'vertical_accuracy': -1,
#    'course': -1,
#    'time': '2014-01-05 20:38:31.832',
#    'altitude': 0,
#    'speed': -1}},
#  {'type': 'Feature',
#   'id': '1790',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1299609486676, 42.35636773057502]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 8,
#    'course': 94.21875,
#    'time': '2014-01-05 20:38:40.022',
#    'altitude': 17,
#    'speed': 26.83313751220703}},
#  {'type': 'Feature',
#   'id': '1800',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.12719935665517, 42.35683795568328]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 70.72496795654297,
#    'time': '2014-01-05 20:38:49.906',
#    'altitude': 21,
#    'speed': 22.82336807250977}},
#  {'type': 'Feature',
#   'id': '1810',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1248425394959, 42.3573450185753]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 85.78125,
#    'time': '2014-01-05 20:38:59.859',
#    'altitude': 18,
#    'speed': 17.50163459777832}},
#  {'type': 'Feature',
#   'id': '1820',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.12330568496516, 42.35744591167499]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 74.83560180664062,
#    'time': '2014-01-05 20:39:09.923',
#    'altitude': 19,
#    'speed': 12.4207010269165}},
#  {'type': 'Feature',
#   'id': '1830',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.12157370483159, 42.35810480029861]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 59.14761352539062,
#    'time': '2014-01-05 20:39:20.054',
#    'altitude': 20,
#    'speed': 17.39902305603027}},
#  {'type': 'Feature',
#   'id': '1840',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.12052275762508, 42.35904432790764]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 2,
#    'course': 6.934349060058594,
#    'time': '2014-01-05 20:39:29.859',
#    'altitude': 19,
#    'speed': 14.07097053527832}},
#  {'type': 'Feature',
#   'id': '1850',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1199276372325, 42.36014340854133]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 47.48955535888672,
#    'time': '2014-01-05 20:39:39.911',
#    'altitude': 14,
#    'speed': 12.21358680725098}},
#  {'type': 'Feature',
#   'id': '1860',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11922916101396, 42.36042735318954]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 60.58976745605469,
#    'time': '2014-01-05 20:39:49.923',
#    'altitude': 14,
#    'speed': 3.921268224716187}},
#  {'type': 'Feature',
#   'id': '1870',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11862791382643, 42.36064573074941]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 62.48538970947266,
#    'time': '2014-01-05 20:39:59.883',
#    'altitude': 14,
#    'speed': 5.51137638092041}},
#  {'type': 'Feature',
#   'id': '1880',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11837651866792, 42.36068774257462]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 12,
#    'course': 60.94520950317383,
#    'time': '2014-01-05 20:40:09.934',
#    'altitude': 13,
#    'speed': 1.969553828239441}},
#  {'type': 'Feature',
#   'id': '1890',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11732454607039, 42.36100843426129]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 66.75499725341797,
#    'time': '2014-01-05 20:40:19.982',
#    'altitude': 15,
#    'speed': 10.02928733825684}},
#  {'type': 'Feature',
#   'id': '1900',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1162451530367, 42.36136620003892]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 68.0447769165039,
#    'time': '2014-01-05 20:40:29.851',
#    'altitude': 18,
#    'speed': 10.90201950073242}},
#  {'type': 'Feature',
#   'id': '1910',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1150972482587, 42.36175928939583]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 8,
#    'course': 66.42045593261719,
#    'time': '2014-01-05 20:40:39.878',
#    'altitude': 15,
#    'speed': 11.01931667327881}},
#  {'type': 'Feature',
#   'id': '1920',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11382294190174, 42.36218261757237]},
#   'properties': {'horizontal_accuracy': 10,
#    'vertical_accuracy': 8,
#    'course': 65.29312896728516,
#    'time': '2014-01-05 20:40:49.851',
#    'altitude': 16,
#    'speed': 10.6596155166626}},
#  {'type': 'Feature',
#   'id': '1930',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11376730242971, 42.36220153305405]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 6,
#    'course': 65.29312896728516,
#    'time': '2014-01-05 20:40:59.928',
#    'altitude': 18,
#    'speed': 0}},
#  {'type': 'Feature',
#   'id': '1940',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11376491759817, 42.36220234375931]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 65.29312896728516,
#    'time': '2014-01-05 20:41:09.910',
#    'altitude': 18,
#    'speed': 0}},
#  {'type': 'Feature',
#   'id': '1950',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1137652483723, 42.36220223126217]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 65.29312896728516,
#    'time': '2014-01-05 20:41:19.950',
#    'altitude': 18,
#    'speed': 0}},
#  {'type': 'Feature',
#   'id': '1960',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11363021949018, 42.36223358688228]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 65.29312896728516,
#    'time': '2014-01-05 20:41:29.895',
#    'altitude': 17,
#    'speed': 1.74218738079071}},
#  {'type': 'Feature',
#   'id': '1970',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11236792797663, 42.36261401689258]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 66.06893920898438,
#    'time': '2014-01-05 20:41:39.883',
#    'altitude': 20,
#    'speed': 12.2541561126709}},
#  {'type': 'Feature',
#   'id': '1980',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.11097090341198, 42.36308697870396]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 72.25531768798828,
#    'time': '2014-01-05 20:41:49.852',
#    'altitude': 22,
#    'speed': 11.00469017028809}},
#  {'type': 'Feature',
#   'id': '1990',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.1105887431041, 42.36320766857657]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 63.31506729125977,
#    'time': '2014-01-05 20:41:59.855',
#    'altitude': 22,
#    'speed': 1.020271420478821}},
#  {'type': 'Feature',
#   'id': '2000',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.10981042474062, 42.36348216938298]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 65.96420288085938,
#    'time': '2014-01-05 20:42:09.869',
#    'altitude': 24,
#    'speed': 10.2703275680542}},
#  {'type': 'Feature',
#   'id': '2010',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.10844950290688, 42.36395551007447]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 65.0372085571289,
#    'time': '2014-01-05 20:42:19.850',
#    'altitude': 21,
#    'speed': 12.1315450668335}},
#  {'type': 'Feature',
#   'id': '2020',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.10713805248479, 42.36444793331297]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 65.28258514404297,
#    'time': '2014-01-05 20:42:29.888',
#    'altitude': 19,
#    'speed': 12.54073238372803}},
#  {'type': 'Feature',
#   'id': '2030',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.10600314100526, 42.36479182427247]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 3,
#    'course': 64.9228515625,
#    'time': '2014-01-05 20:42:39.888',
#    'altitude': 18,
#    'speed': 8.827637672424316}},
#  {'type': 'Feature',
#   'id': '2040',
#   'geometry': {'type': 'Point',
#    'coordinates': [-71.10549107848783, 42.36471378954903]},
#   'properties': {'horizontal_accuracy': 5,
#    'vertical_accuracy': 4,
#    'course': 130.8807067871094,
#    'time': '2014-01-05 20:42:49.911',
#    'altitude': 20,
#    'speed': 3.788084268569946}}]

# %%
xy = np.array([feat['geometry']['coordinates'] for feat in features])
xy

# %%
# Transform the data to EPSG:26986 (Mass. state plane)
proj_in = pyproj.Proj(preserve_units=True, init='epsg:4326', no_defs=True)
crs_out = {'init': 'epsg:26986', 'no_defs': True}
proj_out = pyproj.Proj(preserve_units=True, **crs_out)
xy2 = np.array([pyproj.transform(proj_in, proj_out, c[0], c[1]) for c in xy])
xy2

# %%
# Grab the speed (m/s)
speed = np.array([feat['properties']['speed'] for feat in features])
speed

# %%
# Grab the course. Course is 0 degrees due North, increasing clockwise
course = np.array([feat['properties']['course'] for feat in features])
course

# %%
#### 
angle = np.deg2rad(-course + 90)  # Convert to angle in xy plane
angle

# %%
np.column_stack([np.cos(angle), np.sin(angle)])

# %%
# Normalize the speed to use as the length of the arrows
r = 3*speed / max(speed)
uv = r[:, np.newaxis] * np.column_stack([np.cos(angle), np.sin(angle)])
uv

# %%
xy.shape, xy2.shape, speed.shape, course.shape, angle.shape, uv.shape, r.shape

# %%
import pandas as pd
df = pd.DataFrame(data={'x_in':xy[:,0],
                        'y_in':xy[:,1],
                        'x_out':xy2[:,0],
                        'y_out':xy2[:,1],
                        'speed':speed,
                        'dir':course,
                        'angle':angle,
                        'u':uv[:,0],
                        'v':uv[:,1],
                        'r':r})
df

# %%
# For each point, plot an arrow pointing in the direction of the iPhone's
# course estimate. The arrow length is proportional to the phone's speed
# estimate. For a bigger effect, color each other based on its speed
plt.quiver(xy2[:5,0], xy2[:5,1], uv[:5,0], uv[:5,1], speed[:5])

# root, ext = os.path.splitext(__file__)
mapfile = 'quiver'  + '.html'
# Create the map
mplleaflet.show(path=mapfile, crs=crs_out, tiles=('https://api.mapbox.com/styles/v1/jwasserman/cir51iqda0010bmnic1s5sb71/tiles/256/{z}/{x}/{y}?access_token=pk.eyJ1Ijoiandhc3Nlcm1hbiIsImEiOiJjaW9kNnRiaXUwNGh0dmFrajlqZ25wZnFsIn0.CU4YynqRJkmG1PwWDMBJSA', '<a href="https://mapbox.com/about/maps">© 2017 Mapbox</a> | <a href=https://www.openstreetmap.org/about">© OpenStreetMap</a>'))
